# %%
# %run -n main.py
# %matplotlib inline
jobs = jobs_manager()

# %%
# %run -n main.py
# regions = list(log_progress(load_raw_regions(), every=1))
# subregions = list(load_raw_subregions(log_progress(regions, every=1)))
# subsubregions = list(load_raw_subregions(log_progress(subregions, every=1)))
# dump_regions(subsubregions)
regions = list(load_regions())

# %%
# %run -n main.py
# search_results = load_raw_region_lists(log_progress(regions, every=1))
# search_results = list(log_progress(search_results, every=1))
# dump_region_lists(search_results)
search_results = list(load_region_lists(regions))

# %%
# %run -n main.py
moscow_results = list(filter_region_lists(search_results, u'город Москва'))

# %%
# %run -n main.py
profiles = list(load_profiles(log_progress(search_results, every=100), regions))

# %%
# %run -n main.py
show_buildings_count_by_year(profiles)

# %%
# %run -n main.py
show_floors_count_by_year(profiles)

# %%
# %run -n main.py
show_appartments_count_by_year(profiles)

# %%
# %run -n main.py
dump_data(profiles)
